# %% [markdown]
# <a href="https://colab.research.google.com/github/guyfrancis/dat1001/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Pandas is a Python library that includes a useful datastructure type called 'dataframe' as well as associated code that help manipulate and analyze data.
# Dataframes are good for storing and manipulating data in tabular form, with rows and columns.
#
# Let's start by importing the pandas library.
# We will then create a dictionary containing information about certain people and we will use pandas to convert it to a data frame.

# %%
import pandas as pd

my_dict = { "Name": ["Bob", "Charlie", "Elise"], "Age": [32, 47, 25], "Height (ft)": [5.9, 6.0, 5.2]}

df = pd.DataFrame(my_dict)

df.head()
# Out:
#       Name  Age  Height (ft)
# 0      Bob   32          5.9
# 1  Charlie   47          6.0
# 2    Elise   25          5.2

# %% [markdown]
# ## DataFrame Operations
#
# Now that we have the data stored in a dataframe, we can perform a number of operations.
#
# You can reference a column by using the column header/

# %%
# Reference the column 'Age'
print(df['Age'])
# Out:
# 0    32
# 1    47
# 2    25
# Name: Age, dtype: int64

# %% [markdown]
# You can reference a particular table value with the iloc method, giving the numerical value of the row and column

# %%
# Print the entry in first row (row 0) and second column (column 1) of the data frame
print(df.iloc[0, 1])
# Out:
# 32

# %%
# Print second row (row 1)
print(df.iloc[1])
# Out:
# Name           Charlie
# Age                 47
# Height (ft)        6.0
# Name: 1, dtype: object

# %%
df.describe()
# Out:
#              Age  Height (ft)
# count   3.000000      3.00000
# mean   34.666667      5.70000
# std    11.239810      0.43589
# min    25.000000      5.20000
# 25%    28.500000      5.55000
# 50%    32.000000      5.90000
# 75%    39.500000      5.95000
# max    47.000000      6.00000

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# # Reading Data

# %%
import requests as r
# Define a dictionary of headers to make the request appear browser-like
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'www.google.com' # Optional: can mimic traffic coming from a search engine
}

# %%
url = "https://worldpopulationreview.com/country-rankings/coffee-producing-countries"
page = r.get(url, headers = headers)

# %%
page.status_code
# Out:
# 200

# %%
print(page.text[0:1000])
# Out:
# <!DOCTYPE html><html lang="en"> <head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1"><title>Coffee Producing Countries 2025</title><meta name="description" content="List of coffee producing countries by their production levels, providing data on the biggest coffee producing countries."><link rel="manifest" href="/manifest.webmanifest"><link rel="icon" href="/favicon.ico" sizes="32x32"><link rel="icon" href="/favicon.svg" type="image/svg+xml"><link rel="apple-touch-icon" href="/apple-touch-icon.png"><link rel="sitemap" href="/sitemap-index.xml"><link rel="canonical" href="https://worldpopulationreview.com/country-rankings/coffee-producing-countries"><script type="application/ld+json">{"@context":"https://schema.org","@type":"Article","headline":"Coffee Producing Countries","description":"List of coffee producing countries by their production levels, providing data on the biggest coffee producing countries.","datePublished":"2025-12-12T16:04:05.

# %%
tables = pd.read_html(page.text)
# Out:
# /tmp/ipython-input-3332544648.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(page.text)

# %%
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#     Unnamed: 0                Country Coffee Production 2022 (t)â  \
# 0          NaN                 Brazil                          3.2M
# 1          NaN                Vietnam                            2M
# 2          NaN              Indonesia                        794.8K
# 3          NaN               Colombia                          665K
# 4          NaN               Ethiopia                        496.2K
# ..         ...                    ...                           ...
# 74         NaN  Sao Tome and Principe                             8
# 75         NaN               Suriname                             6
# 76         NaN          New Caledonia                             2
# 77         NaN           Cook Islands                             0
# 78         NaN                  Total                         10.8M
#
#     Coffee Yield 2022
# 0              1694.3
# 1              2979.0
# 2               618.1
# 3               789.4
# 4               668.9
# ..                ...
# 74               58.5
# 75               20.4
# 76              137.5
# 77              587.3
# 78                NaN
#
# [79 rows x 4 columns]
