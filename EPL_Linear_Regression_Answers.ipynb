# %% [markdown]
# # Linear Regression with EPL Data
#
# In this task, you will create separate models for the number of points for EPL teams, based on their goals for, goals against and goal difference.
#
# First let's import all the required libraries and load the latest Premier League table into a `pandas` dataframe.

# %%
# Import required libraries
import requests as r, pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# Create a header that says the request is coming form a browser-like agent (this is to prevent the website blocking our request)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
}
# Make an http request to get the webpage with the following url
url = "http://bbc.co.uk/sport/football/premier-league/table"
page = r.get(url, headers = headers)
if(page.status_code!=200):
    print("Stopping - couldn't get web page.")
else:
    print("Web request status code:", page.status_code)
    # read_html() will find all the tables in the webpage and put them in a list.
    tables = pd.read_html(page.content)
    # In this case, there is only one table, so the length of the list should be 1.
    print("Tables found on webpage:", len(tables))
    EPL = tables[0]
    print("Preparing dataframe of EPL table")
    EPL.insert(loc=0, value=0, column='Position')
    EPL.drop(columns=['Form, Last 6 games, Oldest first'], inplace=True)
    EPL.insert(loc=1, value='', column='Team New')
    rows = EPL.shape[0]
    for x in range(rows):
        EPL.iloc[x, 0]=x+1
        raw_name = EPL.iloc[x, 2]
        if x < 9:
            EPL.iloc[x, 1] = raw_name[1:len(raw_name)]
        elif x >=9:
            EPL.iloc[x, 1] = raw_name[2:len(raw_name)]
    EPL.drop(columns=['Team'], inplace=True)
    EPL.rename(columns={"Team New":"Team"}, inplace=True)
    EPL.rename(columns={'Drawn':"Tied"}, inplace=True)
# Out:
# Web request status code: 200
# Tables found on webpage: 1
# Preparing dataframe of EPL table

# %%
# Take a look at the dataframe
EPL.head()
# Out:
#    Position               Team  Played  Won  Tied  Lost  Goals For  \
# 0         1            Arsenal      31   21     7     3         61
# 1         2    Manchester City      30   18     7     5         60
# 2         3  Manchester United      30   15     9     6         54
# 3         4        Aston Villa      30   15     6     9         40
# 4         5          Liverpool      30   14     7     9         49
#
#    Goals Against  Goal Difference  Points
# 0             22               39      70
# 1             28               32      61
# 2             41               13      54
# 3             37                3      51
# 4             40                9      49

# %% [markdown]
# ## Goals For versus Goals Against
#
# First we'll compare 'Goals For' and 'Goals Against'. We will treat 'Goals For' as the `x` values (independent variable) and 'Goals Against' as the  `y` values (dependent variable).
#
# The code below will be a model for you for the tasks that follow. Run the code to calculate the correlation coefficient and model parameters, and to create a line of best fit graph and residual plot.

# %%
# Pick the relevant columns of the dataframe and convert to numpy arrays
x = np.array(EPL['Goals For'])
y = np.array(EPL['Goals Against'])

# Calculate regression parameters/statistics
m, b, r, p, std_err = stats.linregress(x, y)
print(f"Slope: {m:.3f}")
print(f"Intercept: {b:.3f}")
print(f"r: {r:.3f}")

# Plot scatter plot and line of best fit
y_hat = m*x+b
plt.plot(x, y_hat)
plt.title("Goals For vs Goals Against, EPL 2025-26")
plt.xlabel("Goals For")
plt.ylabel("Goal Against")
plt.scatter(x, y)
plt.show()

# Create residuals
residuals = y-y_hat

# Plot residuals
plt.scatter(x, residuals)
plt.plot([x.min(), x.max()], [0,0])
for i in range(len(residuals)):
    plt.plot([x[i], x[i]], [0, residuals[i]], ':b')
plt.title("Residual Plot for Model (Goals conceded vs goals scored)")
plt.xlabel("Goals scored")
plt.ylabel("Residual: y - y_hat")
plt.show()
# Out:
# Slope: -0.494
# Intercept: 61.197
# r: -0.589

# %% [markdown]
# ## Your Task
#
# We want to see which of the following is the best predictor of the total points a team has:
# - Goals For
# - Goals Against
# - Goal Difference
#
# Your task is to look at the following three different combinations of **bivariate data** from the table.
# - Points (y) vs Goals For (x)
# - Points (y) vs Goals Against (x)
# - Points (y) vs Goal Difference (x)
#
# In each case, we are trying to use the x-values to predict the y-values. For each of these pairs above, do the following:
# - Create a scatter plot
# - Calculate the correlation coefficient and the slope and intercept of the regression line
# - Plot the line of best fit on the same graph as the scatter plot
# - Create an array of residuals and plot them
#
# Once you've done these tasks for each combination above, decide which of 'Goals For', Goals Against' and 'Goal Difference' is the best predictor for the number of points a team has.

# %% [markdown]
# ### Task 1: Points vs Goals For
#
# Put your code for this task in the cell below to do the following for Points vs Goals For.
#
# - Create a scatter plot
# - Calculate the correlation coefficient and the slope and intercept of the regression line
# - Plot the line of best fit on the same graph as the scatter plot
# - Create an array of residuals and plot them

# %%
# Type your code here
x = np.array(EPL['Goals For'])
y = np.array(EPL['Points'])

# Calculate m, b and r
m, b, r, p, std_err = stats.linregress(x, y)
print(f"Slope: {m:.3f}")
print(f"Intercept: {b:.3f}")
print(f"r: {r:.3f}")

y_hat = m*x+b
plt.title("Scatter Plot of Goals For (x) vs Points (y)")
plt.xlabel("Goals For")
plt.ylabel("Points")
plt.scatter(x, y)
plt.plot(x, y_hat)
plt.show()


# Plot residuals
plt.scatter(x, residuals)
plt.plot([x.min(), x.max()], [0,0])
for i in range(len(residuals)):
    plt.plot([x[i], x[i]], [0, residuals[i]], ':b')
plt.title("Residual Plot for Model (Points vs Goals For)")
plt.xlabel("Goals For")
plt.ylabel("Residual: y - y_hat")
plt.show()
# Out:
# Slope: 1.081
# Intercept: -3.331
# r: 0.866

# %% [markdown]
# ### Task 2: Points vs Goals Against
#
# Put your code for this task in the cell below to do the following for Points vs Goals Against.
#
# - Create a scatter plot
# - Calculate the correlation coefficient and the slope and intercept of the regression line
# - Plot the line of best fit on the same graph as the scatter plot
# - Create an array of residuals and plot them

# %%
# Type your code here
x = np.array(EPL['Goals Against'])
y = np.array(EPL['Points'])

# Calculate m, b and r
m, b, r, p, std_err = stats.linregress(x, y)
print(f"Slope: {m:.3f}")
print(f"Intercept: {b:.3f}")
print(f"r: {r:.3f}")

y_hat = m*x+b
plt.title("Scatter Plot of Goals Against (x) vs Points (y)")
plt.xlabel("Goals Against")
plt.ylabel("Points")
plt.scatter(x, y)
plt.plot(x, y_hat)
plt.show()


# Plot residuals
plt.scatter(x, residuals)
plt.plot([x.min(), x.max()], [0,0])
for i in range(len(residuals)):
    plt.plot([x[i], x[i]], [0, residuals[i]], ':b')
plt.title("Residual Plot for Model (Points vs Goals Against)")
plt.xlabel("Goals Against")
plt.ylabel("Residual: y - y_hat")
plt.show()
# Out:
# Slope: -1.276
# Intercept: 93.211
# r: -0.858

# %% [markdown]
# ### Task 3: Points vs Goal Difference
#
# Put your code for this task in the cell below to do the following for Points vs Goal Difference.
#
# - Create a scatter plot
# - Calculate the correlation coefficient and the slope and intercept of the regression line
# - Plot the line of best fit on the same graph as the scatter plot
# - Create an array of residuals and plot them

# %%
# Type your code here
x = np.array(EPL['Goal Difference'])
y = np.array(EPL['Points'])

# Calculate m, b and r
m, b, r, p, std_err = stats.linregress(x, y)
print(f"Slope: {m:.3f}")
print(f"Intercept: {b:.3f}")
print(f"r: {r:.3f}")

y_hat = m*x+b
plt.title("Scatter Plot of Goal Difference (x) vs Points (y)")
plt.xlabel("Goal Difference")
plt.ylabel("Points")
plt.scatter(x, y)
plt.plot(x, y_hat)
plt.show()


# Plot residuals
plt.scatter(x, residuals)
plt.plot([x.min(), x.max()], [0,0])
for i in range(len(residuals)):
    plt.plot([x[i], x[i]], [0, residuals[i]], ':b')
plt.title("Residual Plot for Model (Points vs Goal Difference)")
plt.xlabel("Goal Difference")
plt.ylabel("Residual: y - y_hat")
plt.show()
# Out:
# Slope: 0.735
# Intercept: 40.950
# r: 0.966

# %% [markdown]
# ## Conclusion
#
# Which of these three models is the best? Write a few sentences below to explain your reasoning.

# %% [markdown]
# ** Type your answer here**

# %% [markdown]
# ## Extension
#
# Modify the code at the start to get the league data for another soccer league (or another comparable sports league). Can you build a model to predict total points for the league you have chosen? How does your model compare to the EPL model?
