# %% [markdown]
# # Python So Far Fill-in-the-Blanks
#
# 1. We use square brackets `[` and `]` to enclose a _____________.
# 2. We use curly brackets `{` and `}` for a ______________.
# 3. A dictionary is a set of ______________________ pairs.
# 4. Indexing of data structures starts at ________________.
# 5. For a string `mystr='Python'` the code `mystr[3]` would give you the letter ______.
# 6. When you test for equality, you use _______.
# 7. When you assign a value to a variable you use _____.
# 8. In Python, `elif` is short for _____________.
# 9. Lists and sets are ______________, which means you can change their elements.
# 10. A boolean expression will always evaluate to either ______ or _______.
# 11. In a Python `if` statement such as `if x < 0`, you must put a ____ at the end of the line.
# 12. In a Python `if` statement you must use a ______ to indent the lines of code you want to execute conditionally.
