# %% [markdown]
# # Homework 1
#
# This homework covers the following topics:
#
# - Python data types
# - Python data structures
#
# To complete this homework, you will need to write code to answer all the questions below. You should use formatted printing and/or code comments to make your answers as readable as possible.
#
# Once you have written and tested your code, you should download a copy of this notebook and upload it to D2L via the relevant homework assignment.

# %% [markdown]
# ## Part 1
#
# 1. In Python, define three variables called `x`, `y` and `z`. Give them the values `3`, `7` and `2.718` respectively.
# 2. Using appropriate Python operators and the `print()` function, print the values of each of the following:
#
#    a) $x+y$
#
#    b) $x \times y$
#
#    c) $x^y$
#
# 3. Use the `print()` function and the `type()` function to print the type of `x`, of `x+y`, and of `x+y+z`.
# 4. Use the `%` operator to print the remainder when `y` is divided by `x`.

# %%
# Type your answers to Part 1 here.
# Use the print function to format each answer so it is readable, for example: print("Q1.", your_answer)

# %% [markdown]
# ## Part 2
#
# Strings

# %% [markdown]
# ## Part 3
#
# Booleans

# %% [markdown]
# ## Part 4
#
# Lists

# %% [markdown]
# ## Part 5
#
# Dictionaries

# %% [markdown]
# # Part 6
#
# Bringing it all together!
#
# Look at the English Premier League table on this website: [Premier League Table](https://www.bbc.com/sport/football/premier-league/table)
#
# Suppose you wanted to represent this information in a Python data structure. It would need to include, for each team, the following:
# - Team name
# - League position
# - Games played, won, drawn (tied), lost
# - Goals for, goals against, goal difference (GD)
# - Total points
# - form (last six games where W = win, L = loss, D = draw (tie)
#
# 1. What data structure would you use and how would you store the data? Create an example below, using just the top two teams in the table. Think carefully about the datatype you will use for each data item. The python code should execute with no errors.

# %%
# Type your code below

# %% [markdown]
# 2. Give an example of a data item that could be removed because you can work it out from the other data that you have already in your data structure. If you are able to, list all the data items you could remove without losing any information.
# 3. Why might it be useful for a computer program to be able to store this kind of information in appropriate data structures? What purposes might this serve?
#
# Type your answers to 2 and 3 in the markdown cell below.

# %% [markdown]
# ## Type your answers to 2 and 3 below here.
#
# (your answers)
