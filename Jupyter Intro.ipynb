# %% [markdown]
# This is a markdown cell. It contains information and/or instructions. It does not contain executable code.
#
# The next cell contains Python code. The # symbol is for inline comments in the code, so you can also make comments in a code cell, provided the line starts with the # character.
#
# To run the code in the next cell, first click on the cell so that the cursor is in the cell. Then press SHIFT+ENTER or press the "play" button above.

# %%
# This is a Python code cell. it contains Python code that you can run.
# Press Shift+Enter to run the code below. The output should appear below
# the cell
print("Hello Data!")
# Out:
# Hello Data!

# %% [markdown]
# Look at the icons on the right hand side
# of this cell. Click the icon that allows
# you to add a cell below this.
#
# By default, it will be a code cell.
#
# In the code cell, type some code to print a new message.
# Run the code by pressing Shift+Enter
