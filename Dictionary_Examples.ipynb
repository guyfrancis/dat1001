# %%
d1 = { 'person 1': {'Name':'Alice', 'Age': 37, 'Interests': ['Data Science', 'Coding']},
          'person 2': {'Name':'Bob', 'Age': 42, 'Interests': ['Data Science', 'Cooking']}}

# %%
for key, value in d1.items():
    print(value['Name']+"'s interests are:")
    
    for interest in value['Interests']:
        print("    "+interest)
# Out:
# Alice's interests are:
#     Data Science
#     Coding
# Bob's interests are:
#     Data Science
#     Cooking

# %%
d2 = {'name': ['Bob', 'Alice']}
