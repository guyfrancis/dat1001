# %% [markdown]
# # Jupyter Notebooks Basics
#
# This is a markdown cell. It contains information and/or instructions. It does not contain executable code.
#
# The next cell contains Python code. The # symbol is for inline comments in the code, so you can also make comments in a code cell, provided the line starts with the # character. Any line that does not start with a # character will be interpreted as executable code.
#
# There is one line of code in the next cell:
# ```
# print("Hello Data!")
# ```
#
# To run the code in the next cell, first click on the cell so that the cursor is in the cell. Then press **SHIFT+ENTER** or press the "play" button above.

# %%
# This is a Python code cell. it contains Python code that you can run.
# Press Shift+Enter to run the code below. The output should appear below the cell
print("Hello Data!")

# %% [markdown]
# ## Exercise 1
#
# The code in the code cells is editable. You can modify it and run it again.
#
# Change the message to be printed in the cell above and then run it again to see the new output. (To change the message, change the words inside the double quotes.)
#
# Once you've done that, run the code below several times to see what it does.

# %%
# Run this code to see what it does.
name = input("Hi! Pleae type your name and press enter.")
print("Hello " + name + ". Nice to meet you.")

# %% [markdown]
# ## Formatting Markdown Cells
#
# You can format the content of markdown cells.
#
# For example, If you start a line with a # in a markdown cell, it becomes an heading.
#
# # This is a heading
#
# Two ## symbols give a second-level heading and three ### symbols give a third-level heading.
#
# ## Second-level heading
#
# ### Third-level heading
#
# In most enviroments, double clicking on a markdown cell allows you to edit the content. To see the rendered content, you can press **SHIFT+ENTER**.

# %% [markdown]
# ## More Markdown Formats
#
# We have seen you can have different headings in the markdown text.
#
# You can also surround text with two stars to make it bold:
#
# **This text is bold**
#
# You can surround text with one star to make it italics
#
# *This is italics*
#
# If you want a bulleted list, you can use the - symbol:
#
# - item 1
# - item 2
# - item 3
#
# If you want a numbered list, write the number followed by a period and a space:
#
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# If you want to illustrate some code in the markdown text, you need to start and end with three back-quotes (```):
#
# ```
# print("Hello World!')
# name = input("What's your name?")
# print("Hello" + name)
# ```
#
# If you want to illustrate a code snippet in line use single back-quotes: `print("Hello World!")`.
#
# You can put hyperlinks in markdown text. Use square brackets for the link title and put the url in regular parentheses immediately after:
#
# [A more complete list of markdown is available here](https://www.markdownguide.org/cheat-sheet/)
#
# Click on the link above to see more markdown tips. Then have a go at the exercises below.

# %% [markdown]
# ## Exercise 2
#
# Create a markdown cell with the following:
#
# - At least two different level headings
# - Some text in bold and some text in italics
# - A bulleted list
# - A link to another webpage

# %% [markdown]
# **Edit this markdown block as your answer to Exercise 2.**
#
# (Double click to edit this block)

# %% [markdown]
# ## Exercise 3
#
# Finally, let's do some more practice with executing code.
#
# Run the code in the cells below. Before executing each cell, look at the code and try to figure out what it will do. Then run it to see if you are right. Ask if you have any questions.

# %%
# What is the output of this code?
x = 3
y = 2
print(x+y)
print(x*y)
print(x/y)
print(x**y)

# %%
# What is the output of this code?
s1 = "football"
s2 = "life"
print(s1 + " is " + s2)

# %%
# What is the output of this code?
a = 12
b = 9
print(a < b, a==b, a > b)

# %%
# What is the output of this code?
p = 4
print(p)
p += 5
print(p)
p *= 2
print(p)
p /= 6
print(p)

# %% [markdown]
# ## Extension
#
# Most notebooks in this class will have an extension task at the end. Extension tasks are **optional** and are designed to stretch your understanding and build further skills.
#
# Here are some challenges for you with using markdown cells.
#
# 1. Use single back-quotes (\` \`) to enclose text you want to appear as inline code in the markdown cell.
# 2. Use triple back-quotes (\``` \```) to encolse text you want appear as a code block in the markdown cell. The triple quotes need to be on separate lines with the code text on a separate line in between.
# 3. Use single dollar signs ($ $) to enclose text you want to appear as inline math in the markdown cell. The math is rendered using LaTeX which is a math mark-up language.
# 4. Use double dollar signs (\$$ \$$) to enclose text you want to appear as a block of math in the markdown cell. The double dollar signs need to be on separate lines with the math on a separate line in between. The math is rendered using LaTeX which is a math mark-up language.
#
# There are some examples below to help you. Add a markdown cell and create examples of your own.

# %% [markdown]
# Here is a sentence with some inline code: `print("Hello World!")`.
#
# Here is a code block:
# ```
# x = 25
# print(x+15)
# if (x > 10):
#     print("x is bigger than 10.")
# else:
#     print("X is not bigger than 10.")
# ```
# Here is some math inline: $ C=\frac{5}{9}(F - 32) $.
#
# Here is a block of math:
# $$
# x = \frac{-b \pm\sqrt{b^2-4ac}}{2a}
# $$
