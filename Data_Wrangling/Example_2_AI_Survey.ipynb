# %% [markdown]
# # Data Wrangling Tasks: AI Survey
#
# In this notebook, you will perform some data processing on the responses to our AI Survey. Many of the data processing tasks in this notebook involve recoding data into new variables to facilitate analysis and comparison to other data.
#
# The AI Survey responses are available in the shared folder in our Jupyter Lab:
#
# `/home/shared/AI_Attitudes.csv`
#
# You can view a [copy of the original survey](https://forms.cloud.microsoft/r/deWtx36fSL) in case you need to remind yourself of the questions and answer options.
#
# Run the code below to load the CSV file into a pandas dataframe. Then perform the following tasks to clean and recode the data. In particular, Task 4 will allow us to compare our responses to the [Pew Research foundation Survey](https://www.pewresearch.org/science/2025/09/17/how-americans-view-ai-and-its-impact-on-people-and-society/).
#
# ## Your Tasks
# 1. Load data into a pandas dataframe.
# 2. Rename columns - they are way too long!
# 3. Drop columns that are not relevant to our analysis.
# 4. Create a column called 'Net Excited-Concerned'. This column will contain an integer value that represents the difference between how excited and concerned a respondent is. Use `survey.describe()` to find summary stats for the 'Net Excited-Concerned' column, as well as other columns.
# 5. Create a new column called 'Excited vs Concerned'. This column will contain the following categorical data, based on each respondent's 'Net Excited-Concerned' score:
#    - More excited than concerned
#    - Equally excited and concerned
#    - More Concerned that excited
# 6. Use this to compare our survey results to the [Pew Research survey](https://www.pewresearch.org/science/2025/09/17/how-americans-view-ai-and-its-impact-on-people-and-society).
# 7. Create a column that gives a count of how many tools people report using, based on their answer to the 'Which of the following AI tools have you used?' question. Use this to create a bar chart showing the distribution for the number of tools people use.
# 8. Finally, think about other questions you might want to ask about the data and any recoding or data processing that might be necessary to answer these questions.
#
# **Be prepared to explain your work to the rest of the class.**

# %%
from datetime import date
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

file = "/home/shared/AI_Attitudes.csv"
survey = pd.read_csv(file)
survey

# %% [markdown]
# ### Rename Columns and Drop Columns
# The column names are way too long. Rename the column to simple one or two word names that convey the key idea about what is in the column. There are 16 columns in total.
# You should also drop the following columns, which we won't use in our research:
# - Email
# - Name
# - Last edit time
# - The final column which has emails for those who want a copy of the report.

# %%
# Type your code here

# %% [markdown]
# ### Create a Net Score
# Create a new column called 'Net Excited-Concerned'. This will give the 'excited' score **minus** the 'concerned' score. For example, if someone gave a score of 5 for how excited they were about AI and 7 for how concerned they were, their net score would be -2.
#
# Once you've created a net score, use `survey.describe()` to see summary stats for this new variable.

# %%
# Type your code here

# %% [markdown]
# ### Create a Categorical Excited vs Concerned Column
#
# Now create a column of categorical data with the following values:
# - 'More excited than concerned' if the 'Net Excited-Concerned' score is positive
# - 'More concerned than excited' if the 'Net Excited-Concerned' score is negative
# - 'Equally excited and concerned' if the 'Net Excited-Concerned' score is zero
#
# The best way to do this is with `np.select()`.

# %%
# Type your code here

# %% [markdown]
# # Count Categorical Values for Excited vs Concerned
#
# Use the `value_counts()` method to create a count of how many of each category there are in the 'Excited vs Concerned' column. Convert your answers to percentages and compare to the Pew Research survey.

# %%
# Type your code here

# %% [markdown]
# ### Create a Total Count for AI Tools Used
# Use the 'Tools' column which lists tools people commonly use (separated by a semicolon) to create a count of how many tools people use and use these data to create a bar chart.

# %%
# Type your code here

# %% [markdown]
# ### More
#
# What other analyses can you do? What questions do you have about the survey responses?
