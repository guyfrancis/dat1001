# %% [markdown]
# # Introduction to BeautifulSoup

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests as r
import re

url = "https://guyfrancis.github.io/Example.html"
headers = { "User-agent": "Data Science Class" }

# %%
response = r.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <style>
# table, th, td {
#   border: 2px solid black;
# }
# body {
# 	background-color:powderblue;
# </style>
# <body>
#
# <h1>This is a Heading</h1>
#
# <p id='p1'>This is a paragraph.</p>
# <p id='p2'>This is another paragraph.</p>
# <a href='https://bbc.com/sport/football'>A link</a><br>
# <a href='https://restcountries.com/v3.1/name/germany?fields=capital'>Another link</a>
# <br>
# <br>
# <h2>Top 5 Planets by Mass</h2>
# <table id='table1'>
# 	<tr>
# 		<th>Planet</th>
#         <th>Mass (kg)</th>
# 	</tr>
#     <tr><td>Jupiter</td><td>1.90 x 10^27</td></tr>
#     <tr><td>Saturn</td><td>5.68 x 10^26</td></tr>
#     <tr><td>Neptune</td><td>1.02 x 10^26</td></tr>
#     <tr><td>Uranus</td><td>8.68 x 10^25</td></tr>
#     <tr><td>Earth</td><td>5.97 x 10^24</td></tr>
# </table>
# </body>
# </html>
