# %% [markdown]
# # Homework 1 - Answers
#
# This homework covers the following topics:
#
# - Python data types
# - Python data structures
#
# To complete this homework, you will need to write code to answer all the questions below. You should use formatted printing and/or code comments to make your answers as readable as possible. Any non-code answers or explanation can be written in a markdown cell.
#
# Once you have written and tested your code, you should download a copy of this notebook and upload it to D2L via the relevant homework assignment.

# %% [markdown]
# ## Part 1
#
# 1. In Python, define three variables called `x`, `y` and `z`. Give them the values `3`, `7` and `2.718` respectively.
# 2. Using appropriate Python operators and the `print()` function, print the values of each of the following:
#
#    a) $x+y$
#
#    b) $x \times y$
#
#    c) $x^y$
#
# 3. Use the `print()` function and the `type()` function to print the type of `x`, of `x+y`, and of `x+y+z`.
# 4. Use the `%` operator to print the remainder when `y` is divided by `x`.

# %%
# Type your answers to Part 1 here.
x = 3
y = 7
z = 2.718
print(x+y)
print(x*y)
print(x**y)
print(type(x), type(x+y), type(x+y+z))
print(y%x)
# Out:
# 10
# 21
# 2187
# <class 'int'> <class 'int'> <class 'float'>
# 1

# %% [markdown]
# ## Part 2
#
# 1. Create a string called `str1` with value "sun" and another string called `str2` with value "flower".
# 2. Print each string on a separate line.
# 3. Create a new string called `str3` by combining the two strings with the `+` operator and print it out.
# 4. Use indexing to print the second character of `str3`.
# 5. Use slicing to print the fourth to seventh characters (inclusive) of `str3`.

# %%
# Type your answers to Part 2 here.
str1 = "sun"
str2 = "flower"
print(str1)
print(str2)
str3 = str1 + str2
print(str3)
print(str3[1])
print(str3[3:7])
# Out:
# sun
# flower
# sunflower
# u
# flow

# %% [markdown]
# ## Part 3
#
# Define two boolean variables `p = True` and `q = False`. Use the print function and appropriate logical operations to print the value of each of the following.
#
# 1. `p and q`
# 2. `p and not(q)`
# 3. `p or q`
# 4. `not(p) or q`

# %%
# Type your answers to Part 3 here.
p = True
q = False
print(p and q)
print(p and not(q))
print(p or q)
print(not(p) or q)
# Out:
# False
# True
# True
# False

# %% [markdown]
# ## Part 4
#
# Creat a list L1 as shown below. Then use it to answer the questions below.
# ```
# L1 = ["Abraham", "Bob", "Carly"]
# ```
#
# 1. Print the whole list.
# 2. Use indexing to print the third element of the list.
# 3. Use the `append()` method to and the name "Diego" to the list.
# 4. Use slicing to print the list composed of the last two elements of `L1`.

# %%
# Type your answers to Part 4 here.
L1 = ["Abraham", "Bob", "Carly"]
print(L1)
print(L1[2])
L1.append("Diego")
print(L1[2:4])
# Out:
# ['Abraham', 'Bob', 'Carly']
# Carly
# ['Carly', 'Diego']

# %% [markdown]
# ## Part 5
#
# The dictionary below contains information about a scheduled international flight.
# ```
# flight = {"Number":"BA219", "Departure Airport": "LHR", "Destination": "DEN", "Date":"01-07-2026", "Duration (hr, min)":(9, 50)}
# ```
#
# 1. Create the dictionary in Python (just copy and paste) and then use `print()` to print the whole dictionary.
# 2. Use indexing with the key "Number" to print the flight number.
# 3. Use indexing with the key "Destination" to print the destination.
# 4. USe indexing to print the number of minutes in the tuple corresponding to the key "Duration (hr, min)".

# %%
# Type your answers to Part 5 here.
flight = {"Number":"BA219", "Departure Airport": "LHR", "Destination": "DEN", "Date":"01-07-2026", "Duration (hr, min)":(9, 50)}
print(flight)
print(flight["Number"])
print(flight["Destination"])
print(flight["Duration (hr, min)"][1])
# Out:
# {'Number': 'BA219', 'Departure Airport': 'LHR', 'Destination': 'DEN', 'Date': '01-07-2026', 'Duration (hr, min)': (9, 50)}
# BA219
# DEN
# 50

# %% [markdown]
# ## Part 6
#
# Bringing it all together!
#
# Look at the English Premier League table on this website: [Premier League Table](https://www.bbc.com/sport/football/premier-league/table)
#
# Suppose you wanted to store this information in a Python data structure. It would need to include, for each team, the following:
# - Team name
# - League position
# - Games played, won, drawn (tied), lost
# - Goals for, goals against, goal difference (GD)
# - Total points
# - form (last six games where W = win, L = loss, D = draw (tie)
#
# 1. What data structure would you use and how would you store the data? Create an example below, using just the **top two teams** in the table. Think carefully about the datatype you will use for each data item. The Python code should execute with no errors. *Note: you can hit the enter key at any point so that your data structure runs over multiple lines*.

# %%
# Type your code below creating an appropriate data structure for the top two teams only.
EPL_table = [{"Team":"Arsenal", "League Position": 1, "Games Played":21, "Won":15, "Tied": 4, 
              "Lost": 2, "Goals For":40, "Goals Against": 14, "Goal Difference": 26, "Points":49, "Form":"WWWWWWD"},
            {"Team":"Manchester City", "League Position": 2, "Games Played":21, "Won":13, "Tied": 4, 
              "Lost": 4, "Goals For":45, "Goals Against": 19, "Goal Difference": 26, "Points":43, "Form":"WWWDDD"}         
            ]

# %% [markdown]
# 2. Give an example of a data item that could be removed because you can work it out from the other data that you have already in your data structure. What are the benefits of removing data items that can be worked out from other data?
# 3. Why might it be useful for a computer program to be able to store this kind of information in an appropriate data structure? What purposes might this serve?
#
# Type your written answers to 2 and 3 in the markdown cell below.

# %% [markdown]
# ## Type your answers to 2 and 3 below here.
#
# 2. You can remove one of the following: goals for, goals against, goal difference. You can also remove one of games played, games won, games lost, games tied. You could possibly remove league position if you keep the points, goal difference and goals scores. Except in very rare circumstances you could recover position from these other data items. You could remove points if you know that teams get 3 points for a win and 1 for a tie.
# 3. You could use this information for creating a website sports page (like BBC Sport) or for creating a model to predict outcomes of future matches, or who will win the league.

# %% [markdown]
# ## End of Assignment
#
# Don't forget to save your homework on your own computer, network drive or GitHub account. Then upload it to the assignment on D2L.
